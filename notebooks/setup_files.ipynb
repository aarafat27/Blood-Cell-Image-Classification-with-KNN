# %% [markdown]
# ### imports and path

# %%
import os
raw_root = r"C:\Users\Arafat\Desktop\IMA Project\data\raw"
print(os.listdir(raw_root))
print("TRAIN subfolders:", os.listdir(os.path.join(raw_root, "TRAIN")))
# Out:
# ['TEST', 'TRAIN']
# TRAIN subfolders: ['EOSINOPHIL', 'LYMPHOCYTE', 'MONOCYTE', 'NEUTROPHIL']

# %%
import os
import sys

project_root = r"C:\Users\Arafat\Desktop\IMA Project"
if project_root not in sys.path:
    sys.path.append(project_root)

from src import config
from src.utils import set_random_seed

config.make_all_dirs()
set_random_seed(42)
# Out:
# [utils] Random seed set to 42
